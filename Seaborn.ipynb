# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv')
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# # Lineplot

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
sns.lineplot(x=df['year'],y=df['passengers'],data=df,dashes=True,hue='month',style='month',
             legend='full')
plt.title('SEA_Born')
plt.xlabel('yea')
plt.legend(loc='lower right')
plt.grid(True,alpha=0.5,linewidth=0.8,linestyle='--',color='r')
plt.show()

# %%
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
mpg=sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
sns.lineplot(x='mpg',y='horsepower',data=mpg,hue='origin',style='origin',dashes=False,
             markers=['o','*','^'],palette='summer')
plt.show()

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Displot

# %%
sns.displot(x='total_bill',y='tip',data=tips,hue='sex',palette='hot',
            rug=True,)

plt.grid(True)
plt.show()

# %%
sns.displot(x='total_bill',data=tips,
            rug=True,)
plt.xlabel('total_expense')
plt.show()
plt.grid(True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='white')
sns.displot(x='size',data=tips,kde=True,hue='sex',col='sex',palette='hot',rug=True)
plt.show()

# %% [markdown]
# # Barplot

# %%
penguins=sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_style('white')
sns.barplot(x='species',y='body_mass_g',data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
sns.barplot(x=tips.day,y=tips.total_bill,data=tips,order=(['Sun','Thur','Fri','Sat']),hue='sex',
           saturation=10,palette='hot',dodge=False,capsize=.1,
            
            hue_order=['Male','Female'],estimator=np.sum,ci=50,errcolor='g',errwidth=5,
            
           )

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
sns.barplot(x=tips.day,y=tips.total_bill,data=tips,order=(['Sun','Thur','Fri','Sat']),hue='sex',
           saturation=10,palette='hot',capsize=.1,
            
            hue_order=['Male','Female'],estimator=np.sum,ci=5,errcolor='g',errwidth=5,
            
           )

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
sns.barplot(x=tips.day,y=tips.total_bill,data=tips,order=(['Sun','Thur','Fri','Sat']),hue='sex',
           saturation=10,palette='hot',alpha=0.7,linestyle='-.',linewidth=5,edgecolor='k',
            
            hue_order=['Male','Female'],estimator=np.sum,ci=50,errcolor='y',errwidth=5,
            hatch='+',
            
           )
# plt.title('Total_Bill Vs Day',fontdict={'fontsize':20,'fontweight':'bold'})
plt.ylabel('Total_Bill (Sum)')
plt.title('Total_Bill Vs Day',fontsize=20,fontweight='bold')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='white')
a={"alpha":0.5,"linestyle":'-.',"linewidth":5,"palette":'summer'}
sns.barplot(y=tips.day,x=tips.total_bill,data=tips,order=(['Sun','Thur','Fri','Sat']),hue='sex',
           saturation=10,edgecolor='k',
            
            hue_order=['Male','Female'],estimator=np.sum,ci=50,errcolor='y',errwidth=5,**a
            
           )
# plt.title('Total_Bill Vs Day',fontdict={'fontsize':20,'fontweight':'bold'})
plt.ylabel('Total bill (sum)')
plt.title('Total_Bill Vs Day',fontsize=20,fontweight='bold')
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatterplot

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(y='fare',x=titanic.age,data=titanic,hue='sex',size='fare',palette='hot',
                sizes=(100,300),style='alive'
               )
# plt.colorbar(mappable='fare',vmin=5,vmax=90)
 

plt.show()

# %%
titanic['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %% [markdown]
# # x=object,y=float, Scatterplot

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(y='age',x=titanic.who,data=titanic,hue='alive',size='class',palette='hot',
                sizes=(100,300),style='alive'
               )

plt.show()

# %%
titanic.groupby('alive')['sex','alive'].count()
# Out:
# C:\Users\onspe\AppData\Local\Temp\ipykernel_1996\2121779716.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   titanic.groupby('alive')['sex','alive'].count()
#        sex  alive
# alive
# no     549    549
# yes    342    342

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x='day',y='total_bill',data=tips,hue='sex'
               ,palette='hot',markers=['*','o'],style='sex', size='tip',sizes=(300,500)
               
               ,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # HeatMap

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
color1=sns.choose_colorbrewer_palette('qualitative',as_cmap=False)
# Out:
# interactive(children=(Dropdown(description='name', options=('Set1', 'Set2', 'Set3', 'Paired', 'Accent', 'Paste…

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x='tip',y='total_bill',data=tips,hue='day', size='day'
               ,style='sex',sizes=(300,500)
                              
               ,)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # HEATMAP

# %% [markdown]
# Table must contain only NUMERIC VALUES

# %%
new_tips=tips.drop(['sex','smoker','day'],axis=1).set_index('time') 
new_tips
# Out:
#         total_bill   tip  size
# time
# Dinner       16.99  1.01     2
# Dinner       10.34  1.66     3
# Dinner       21.01  3.50     3
# Dinner       23.68  3.31     2
# Dinner       24.59  3.61     4
# ...            ...   ...   ...
# Dinner       29.03  5.92     3
# Dinner       27.18  2.00     2
# Dinner       22.67  2.00     2
# Dinner       17.82  1.75     2
# Dinner       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(new_tips)
# Out:
# <AxesSubplot:ylabel='time'>

# %%
mpg=sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
new_mpg=mpg.drop(['name'],axis=1).set_index('origin').groupby('origin').sum()
new_mpg
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  1952.4        291        7640.0      5478.0  169631        1175.1
# japan   2405.6        324        8114.0      6307.0  175477        1277.6
# usa     5000.8       1556       61229.5     29167.0  837121        3743.4
#
#         model_year
# origin
# europe        5307
# japan         6118
# usa          18827

# %%
plt.figure(figsize=(16,9))
sns.heatmap(new_mpg,linecolor='green',linewidth=3,annot=True)
# Out:
# <AxesSubplot:ylabel='origin'>

# %%
new_mpg.groupby('origin').count()
# Out:
#         mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe    1          1             1           1       1             1
# japan     1          1             1           1       1             1
# usa       1          1             1           1       1             1
#
#         model_year
# origin
# europe           1
# japan            1
# usa              1

# %%
k=mpg.groupby('origin').cylinders.value_counts().unstack()

# %%
sns.heatmap(k,annot=True,linecolor='green',linewidth=2,cmap='Greens')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
mn=mpg.groupby('origin').cylinders.value_counts().unstack()
mn
# Out:
# cylinders    3     4    5     6      8
# origin
# europe     NaN  63.0  3.0   4.0    NaN
# japan      4.0  69.0  NaN   6.0    NaN
# usa        NaN  72.0  NaN  74.0  103.0

# %%
plt.figure(figsize=(16,9))
annot={'alpha':1,"color":'k','fontstyle':'italic','backgroundcolor':'w','rotation':'vertical'}
cbar={'orientation':'horizontal','shrink':1,'extend':'min','extendfrac':0.1,
     'ticks':np.arange(0,100,10),}
x=sns.heatmap(mn,annot=True,cmap='Reds', linewidth=1.5,linecolor='k',
            xticklabels=['a','b','c','d'],yticklabels=['America','Japan','Canda'],
            cbar_kws=cbar
                      
           ,)
x.set(title="Heatmap of Country",xlabel='Type of Cylinders',ylabel='Name of Country')
sns.set(font_scale=2)



# plt.ylabel('Origin',fontsize=15,color='r',fontweight='bold',cmap='b')
plt.show()

# %%
o=df.groupby(['year','passengers']).sum()
o
# Out:
#                             month
# year passengers
# 1949 104                 November
#      112                  January
#      118         FebruaryDecember
#      119                  October
#      121                      May
# ...                           ...
# 1960 472                      May
#      508                September
#      535                     June
#      606                   August
#      622                     July
#
# [135 rows x 1 columns]

# %%
abc=mpg.drop(['origin','name'],axis=1)
abc
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
plt.figure(figsize=(16,9))
m=sns.heatmap(mpg.corr(),linewidth=2,linecolor='k',annot=True)
m.tick_params(size=50,color='g',labelsize=20,labelcolor='k')
# sns.set(font_scale=2)

# %% [markdown]
# # Pairplot

# %%
plt.figure(figsize=(16,9))
sns.pairplot(tips,hue='sex')
plt.show()

# %%
color123=sns.choose_colorbrewer_palette('qualitative')
color123
# Out:
# interactive(children=(Dropdown(description='name', options=('Set1', 'Set2', 'Set3', 'Paired', 'Accent', 'Paste…
# [(0.8941176470588235, 0.10196078431372557, 0.10980392156862737),
#  (0.21568627450980393, 0.4941176470588236, 0.7215686274509804),
#  (0.3019607843137256, 0.6862745098039216, 0.29019607843137263),
#  (0.5960784313725492, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.9999999999999998, 1.0, 0.19999999999999996),
#  (0.6509803921568629, 0.33725490196078434, 0.1568627450980391),
#  (0.9686274509803922, 0.5058823529411766, 0.7490196078431374),
#  (0.6, 0.6, 0.6)]

# %%
plt.figure(figsize=(16,9))
sns.pairplot(mpg,hue='origin',hue_order=['japan','europe','usa'],palette=color123,
             markers=["s","D","o"],dropna=True,diag_kind='hist'
             
             ,)
plt.show()

# %%
mpg.pivot_table(index=['origin','cylinders']).count()
# Out:
# acceleration    9
# displacement    9
# horsepower      9
# model_year      9
# mpg             9
# weight          9
# dtype: int64

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(16,9))
sns.countplot(x='cylinders',data=mpg,dodge=True,hue='origin',hatch='/',ec='r',lw=2)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
mpg.groupby(['cylinders','origin'])['cylinders'].count().unstack()
# Out:
# origin     europe  japan    usa
# cylinders
# 3             NaN    4.0    NaN
# 4            63.0   69.0   72.0
# 5             3.0    NaN    NaN
# 6             4.0    6.0   74.0
# 8             NaN    NaN  103.0

# %%
sns.countplot(x='pclass',data=titanic,dodge=True,hue='sex',ec='k',lw=2,palette='flag')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %% [markdown]
# # relplot

# %%
plt.figure(figsize=(16,9))
sns.relplot(

y='fare',x='age',data=titanic,hue='sex',kind='scatter',size='pclass',sizes=(300,400),
    col='sex',row='pclass',style='sex',palette='hot',col_order=['female','male'], height=10,
    aspect=1,

    markers=['*','^']
)

# %% [markdown]
# # To shade the table according to the intensity of values

# %%
tips.style.background_gradient()
# Out:
# <style type="text/css">
# #T_33d76_row0_col0, #T_33d76_row4_col1, #T_33d76_row18_col0, #T_33d76_row37_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_33d76_row0_col1, #T_33d76_row67_col0, #T_33d76_row67_col1, #T_33d76_row67_col6, #T_33d76_row82_col6, #T_33d76_row92_col1, #T_33d76_row111_col1, #T_33d76_row111_col6, #T_33d76_row222_col6, #T_33d76_row236_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# ...

# %%
titanic.style.background_gradient(cmap='Accent',text_color_threshold=10)
# Out:
# <style type="text/css">
# ...
